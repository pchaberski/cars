# %% [markdown]
# # Notebook for running training on Colab

# %% [markdown]
# 1. Check if GPU is available (and which model):

# %%
# !nvidia-smi

# %% [markdown]
# 2. Check if you're on Colab:

# %%
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False

# %% [markdown]
# 3. If on colab, connect to Google Drive project folder and recreate local environment (after that, runtime restart and re-exuction of all cells are needed):

# %%
import os
if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    os.chdir('/content/drive/My Drive/gdprojects/cars')
    try:
        import mat4py
        REQS_INSTALLED = True
    except:
        REQS_INSTALLED = False
    if not REQS_INSTALLED:
        # !pip install -r dev_requirements.txt
        # !pip install -r prod_requirements.txt
else:
    os.chdir('C:/Users/pchaberski/Google Drive/gdprojects/cars')

# %% [markdown]
# 4. Run training:

# %%
exec(open('train.py').read())
